# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
import pickle

# %%
data = pd.read_csv('train.csv').drop(columns=['id'])
data
# Out:
#             lat        lon     score
# 0     56.228300  43.945535  0.080523
# 1     56.834244  53.141543  0.104424
# 2     45.042299  41.990170  0.067615
# 3     59.849408  30.387762  0.088038
# 4     59.839643  30.304308  0.099686
# ...         ...        ...       ...
# 3079  55.674584  37.279505  0.531557
# 3080  55.784909  49.188791  0.101631
# 3081  55.118828  61.462996  0.125265
# 3082  55.649052  37.533877  0.322601
# 3083  56.317263  43.887981  0.137444
#
# [3084 rows x 3 columns]

# %%
X_train = data.drop(columns = ['score'])
y_train = data.score

# %%
gbс_parametrs = {'learning_rate': 0.15, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300, 'subsample': 1.0}
regressor = GradientBoostingRegressor(**gbс_parametrs)
regressor.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.15, max_depth=15, max_features='sqrt',
#                           n_estimators=300)

# %%
with open('model.pickle', 'wb') as file:
  pickle.dump(regressor, file)

# %% [markdown]
# Важно сказать, что генерация признаков была произведена. Но так из features.csv даже 3 признака, подобранными PCA, увеличивали MAE, было решено не использовать их вовсе
#
# GridSearch был использован для генерации лучших параметров для данных.

# %% [markdown]
# Это GridSearch

# %%
# from sklearn.ensemble import GradientBoostingRegressor
# from sklearn.model_selection import train_test_split, GridSearchCV

# from sklearn.metrics import make_scorer
# import numpy as np

# param_grid = {
#     'max_depth': [8, 11, 15],
#     'n_estimators': [300, 400, 500],
#     'learning_rate': [0.7, 0.15, 0.2],
#     'min_samples_split': [2, 5, 8],
#     'subsample': [0.6, 0.8, 1.0],
#     'max_features': ['auto', 'sqrt', 'log2'],
#     'min_samples_leaf': [1, 2, 4], 
# }

# regressor = GradientBoostingRegressor(random_state=42)

# grid_search = GridSearchCV(regressor, param_grid, cv=3,  scoring='neg_mean_absolute_error', verbose=1, n_jobs=-1)
# grid_search.fit(X_train, y_train)

# print("Best parameters:", grid_search.best_params_)

# best_regressor = grid_search.best_estimator_
# best_regressor.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 2187 candidates, totalling 6561 fits
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:547: FitFailedWarning:
# 2187 fits failed out of a total of 6561.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 708 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py", line 1467, in wrapper
# ...
